# %%
A.info()

# %%
A.head()

# %%
A=pd.read_excel(r"C:\Users\user\Downloads\automobile_data .xlsx")

# %%
import pandas as pd

# %%
A
# Out:
#             make fuel_type num_of_doors   body_style drive_wheels  \
# 0    alfa-romero       gas          two  convertible          rwd
# 1    alfa-romero       gas          two  convertible          rwd
# 2    alfa-romero       gas          two    hatchback          rwd
# 3           audi       gas         four        sedan          fwd
# 4           audi       gas         four        sedan         4wd
# ..           ...       ...          ...          ...          ...
# 198        volvo       gas         four        sedan          rwd
# 199        volvo       gas         four        sedan          rwd
# 200        volvo       gas         four        sedan          rwd
# 201        volvo    diesel         four        sedan          rwd
# 202        volvo       gas         four        sedan          rwd
#
#     engine_location  wheel_base  length  width  height  curb_weight  \
# 0             front        88.6   168.8   64.1    48.8         2548
# ...

# %%
A.duplicated().any()
# Out:
# np.False_

# %%
A.columns

# %%
A. drop_duplicates()
# Out:
#             make fuel_type num_of_doors   body_style drive_wheels  \
# 0    alfa-romero       gas          two  convertible          rwd
# 1    alfa-romero       gas          two  convertible          rwd
# 2    alfa-romero       gas          two    hatchback          rwd
# 3           audi       gas         four        sedan          fwd
# 4           audi       gas         four        sedan         4wd
# ..           ...       ...          ...          ...          ...
# 198        volvo       gas         four        sedan          rwd
# 199        volvo       gas         four        sedan          rwd
# 200        volvo       gas         four        sedan          rwd
# 201        volvo    diesel         four        sedan          rwd
# 202        volvo       gas         four        sedan          rwd
#
#     engine_location  wheel_base  length  width  height  curb_weight  \
# 0             front        88.6   168.8   64.1    48.8         2548
# ...

# %%
# to count duplicates
A.duplicated().sum()
# Out:
# np.int64(1)

# %%
# actual duplicate
A[A.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [make, fuel_type, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, compression_ratio, horsepower, city_mpg, highway_mpg, price]
# Index: []

# %%
A[A.duplicated()]
# Out:
# Empty DataFrame
# Columns: [make, fuel_type, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, compression_ratio, horsepower, city_mpg, highway_mpg, price]
# Index: []

# %%
# to check for nulls
A.isna().sum()
# Out:
# make                 0
# fuel_type            0
# num_of_doors         2
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# compression_ratio    0
# horsepower           0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
A.drop_duplicates(inplace =  True)

# %%
A
# Out:
#             make fuel_type num_of_doors   body_style drive_wheels  \
# 0    alfa-romero       gas          two  convertible          rwd
# 1    alfa-romero       gas          two  convertible          rwd
# 2    alfa-romero       gas          two    hatchback          rwd
# 3           audi       gas         four        sedan          fwd
# 4           audi       gas         four        sedan         4wd
# ..           ...       ...          ...          ...          ...
# 198        volvo       gas         four        sedan          rwd
# 199        volvo       gas         four        sedan          rwd
# 200        volvo       gas         four        sedan          rwd
# 201        volvo    diesel         four        sedan          rwd
# 202        volvo       gas         four        sedan          rwd
#
#     engine_location  wheel_base  length  width  height  curb_weight  \
# 0             front        88.6   168.8   64.1    48.8         2548
# ...

# %%
A= A.reset_index(drop=True)

# %%
A
# Out:
#             make fuel_type num_of_doors   body_style drive_wheels  \
# 0    alfa-romero       gas          two  convertible          rwd
# 1    alfa-romero       gas          two  convertible          rwd
# 2    alfa-romero       gas          two    hatchback          rwd
# 3           audi       gas         four        sedan          fwd
# 4           audi       gas         four        sedan         4wd
# ..           ...       ...          ...          ...          ...
# 197        volvo       gas         four        sedan          rwd
# 198        volvo       gas         four        sedan          rwd
# 199        volvo       gas         four        sedan          rwd
# 200        volvo    diesel         four        sedan          rwd
# 201        volvo       gas         four        sedan          rwd
#
#     engine_location  wheel_base  length  width  height  curb_weight  \
# 0             front        88.6   168.8   64.1    48.8         2548
# ...

# %%
# value count for the column data type object with fall loop

# %%
# value count using fall loop
for x in A.columns:
    print(A[x].value_counts())

# %%
# unique values in a column
A['make'].unique()

# %%
# How many value counts
A['make'].value_counts()

# %%
# to get the number of the unique value
A['make'].nunique()

# %%
# to analysis using a chart 'h' to flake the bar chart
A["make"].value_counts().plot(kind="barh", color='black')

# %%
A["body_style"].value_counts().plot()

# %%
A["body_style"].value_counts().plot(kind="pie")

# %%
A["price"].value_counts().plot()

# %%
pd.crosstab(A["make"], A['fuel_type']).plot()

# %%
# visaulazation with title
pd.crosstab(A["make"], A['fuel_type']).plot(kind = 'bar', title= 'make and fueltype ')

# %%
# group by
A.groupby('make')['price'].sum()

# %%
A.groupby('make')['price'].mean()

# %%
# group by sort asc for asc,
A.groupby('make')['price'].mean(). sort_values()

# %%
 # if you want TO sort it descending asc = fasle
A.groupby('make')['price'].mean(). sort_values(ascending = False)

# %%
# sort by head
A.groupby('make')['price'].mean(). sort_values(). head()

# %%
# sort by head with chart
A.groupby('make')['price'].mean(). sort_values(). head(). plot(kind = 'pie')

# %%
# to groupby many agg  
A.groupby('make')['price']. agg(['sum', 'mean','count'])

# %%
# comparison on tabular form using crosstab and index
pd.crosstab(index=[A['make'],A['fuel_type']], columns= A['num_of_doors'])

# %%
A.groupby(['make', 'fuel_type'])['price'].mean().sort_values()

# %%
A.columns

# %%
A.groupby(['engine_location'])['price'].mean().sort_values()

# %%
# eng location and price
# eng location and number of cyclinder and price
A.groupby(['engine_location', 'num_of_cylinders'])['price']. mean().sort_values(ascending = False)

# %%
A.groupby(['engine_location', 'engine_size'])['price'].mean().sort_values()

# %%
# engine location, sum and avg of price,avg engine size
A.groupby('engine_location').agg({'price':['mean', 'sum'],'engine_size':'mean'})

# %%
# engine location and avg price,avg engine size
A.groupby('engine_location').agg({'price':'mean', 'engine_size':'mean'})

# %%
A['num_of_cylinders'].unique()

# %%
A['num_of_cylinders']= A ['num_of_cylinders']. replace('tow','two')

# %%
A['num_of_cylinders'].unique()

# %%
A.columns

# %%
# how many of this car make use different fuel system
pd.crosstab(A['make'],A['fuel_system'])

# %%
# to plot a chart of the different engine type
A["engine_type"].value_counts().plot(kind="bar")

# %%
# the make and their average curb weight,length,width and height
A.groupby('make')[['curb_weight', 'length', 'width', 'height']]. mean()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mp=A.groupby('make')['price'].mean().sort_values(ascending=False)

# %%
mp

# %%
# bar chart
plt.barh(mp.index,mp.values, color='green')

# %%
 #for rotation of bar chart,title, X and Y Label
plt.barh(mp.index,mp.values, color='brown')
plt.xticks(rotation=75)
plt.xlabel('make')
plt.ylabel('price')
plt.title('average price by title')

# %%
# chart with body style and curb weight avg
pd.crosstab(A['body_style'],A['curb_weight']).mean().plot(kind='line', color='green')

# %%
sns.barplot(x='make', y='price', data=mp, palette= 'cool')
plt.xticks(rotation=90)
plt.xlabel(' ') # to remove the label
plt.ylabel(' ')

# %%
# to make it run with sns reset index
mp=A.groupby('make')['price'].mean().sort_values(ascending=False).reset_index()

# %%
mp

# %%
sns.barplot(x='price', y='make', data=A, estimator='mean', color='black')

# %%
m=A.groupby('make')['price'].mean().sort_values(ascending=False)

# %%
m

# %%
# line chart
plt.plot(m.values, m.index, color='orange')

# %%
sns.lineplot(x='price',y='make', data=)

# %% [markdown]
# # histogram

# %%
# pandas
A['price'].plot(kind="hist")

# %%
# plt
plt.hist(A['price'], color='green')

# %%
sns.histplot(A['price'],color='pink')

# %% [markdown]
# # scattered plot

# %%
#pandas
A.plot(kind='scatter', x='curb_weight', y='price', color='purple')

# %%
#plt
plt.scatter(A['length'], A['width'], color='red')

# %%
sns.scatterplot(x='price', y='engine_size', data=A, color='yellow')

# %%
sns.regplot(x='price', y='engine_size',data=A, color='brown')

# %%
#pie chart
m.plot.pie()

# %%
#
plt.pie(m,labels =m.index)

# %%
plt.pie(m,labels =m.index, autopct='%1.0f%%')

# %%
plt.pie(m,labels =m.index, autopct='%1.f%%')

# %%
# boxplot - pandas USED FOR DISTRIBUTION
A.boxplot(column='price')

# %%
A.boxplot(column='price', by = 'fuel_type')

# %%
sns.boxplot(x='price', y = 'fuel_type', data=A)

# %%
sns.boxplot(x='make', y = 'price', data=A)
plt.xticks(rotation=70)

# %%
# merge

# %%
pd.merge(G,P, on = 'engine_location', how= 'left')

# %%
# concat

# %%
F=pd.concat([G,P]).reset_index(drop=True)

# %%
F

# %%
# filter
A[A['make'] == 'audi']

# %%
G=A[A['make'] == 'audi']

# %%
G

# %%
P=A[A['fuel_type'] == 'gas']

# %%
P
